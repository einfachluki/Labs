# %% [markdown]
# # Case Study

# %% [markdown]
# ## 1. User Exerperience

# %%
#pip install fuzzywuzzy

# %%
#pip install --user pyinputplus

# %%
import pandas as pd
import random
from fuzzywuzzy import process
import pyinputplus as pyip
# Out:
# /Users/lukasbauerschmidt/opt/anaconda3/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
hotsongs = pd.read_csv("hot songs.csv")
pd.set_option('display.max_rows', None)
hotsongs
# Out:
#                             songs  \
# 0                         Flowers
# 1                       Kill Bill
# 2                      Last Night
# 3                          Unholy
# 4                        Creepin'
# 5                         Cuff It
# 6                       Anti-Hero
# 7                     Die For You
# 8                 I'm Good (Blue)
# 9                       As It Was
# 10                      Rich Flex
# 11                Just Wanna Rock
# 12        Thought You Should Know
# 13            Boy's A Liar, Pt. 2
# 14                  Made You Look
# 15            Under The Influence
# 16                    Golden Hour
# 17                      You Proof
# 18          Rock And A Hard Place
# 19        Something In The Orange
# 20                      Thank God
# 21                      Bad Habit
# 22             Going, Going, Gone
# 23                       Escapism
# 24  Superhero (Heroes & Villains)
# 25                  Lavender Haze
# 26                      Calm Down
# 27                        Players
# 28                          Shirt
# 29                     Sure Thing
# 30       The Kind Of Love We Make
# 31             Heart Like A Truck
# 32   Bzrp Music Sessions, Vol. 53
# 33                         Snooze
# 34              Until I Found You
# 35                     Wait For U
# 36    I Like You (A Happier Song)
# 37               I Wrote The Book
# 38                      Bebe Dame
# 39                     Tomorrow 2
# 40                About Damn Time
# 41              Wait In The Truck
# 42   She Had Me At Heads Carolina
# 43                 Nobody Gets Me
# 44     What My World Spins Around
# 45                    Unstoppable
# 46            One Thing At A Time
# 47                 Whiskey On You
# 48                          Dawns
# 49                     Love Again
# 50              Everything I Love
# 51                     Lift Me Up
# 52                    Que Vuelvas
# 53                            Low
# 54               Tennessee Orange
# 55                  X Si Volvemos
# 56                    Bloody Mary
# 57                  Handle On You
# 58              What He Didn't Do
# 59                      Freestyle
# 60                    Wild As Her
# 61                    Spin Bout U
# 62                     You Didn't
# 63     Growin' Up And Gettin' Old
# 64                       Nonsense
# 65                   Here With Me
# 66               The Color Violet
# 67                            AMG
# 68                          10:35
# 69                     La Bachata
# 70                      Forget Me
# 71        Shut Up My Moms Calling
# 72                          Blind
# 73                            OMG
# 74                       No Se Va
# 75                Love You Better
# 76                       La Jumpa
# 77                            PRC
# 78       That's What Tequila Does
# 79                  Love Language
# 80                  Tennessee Fan
# 81                          Ditto
# 82           Watch The World Burn
# 83                          Human
# 84                     In Ha Mood
# 85                       Back End
# 86                    Do It Again
# 87                        Hey Mor
# 88                Too Many Nights
# 89           Ghost In The Machine
# 90                  Fin de Semana
# 91                           Snap
# 92              California Breeze
# 93   I'm Not Here To Make Friends
# 94                  Gato de Noche
# 95                     Yandel 150
# 96                 Heart To Heart
# 97            Next Thing You Know
# 98    Never Gonna Not Dance Again
# 99                      Open Arms
#
#                                             artist
# 0                                      Miley Cyrus
# 1                                              SZA
# 2                                    Morgan Wallen
# 3                           Sam Smith & Kim Petras
# 4             Metro Boomin, The Weeknd & 21 Savage
# 5                                          Beyonce
# 6                                     Taylor Swift
# 7                                       The Weeknd
# 8                        David Guetta & Bebe Rexha
# 9                                     Harry Styles
# 10                               Drake & 21 Savage
# 11                                    Lil Uzi Vert
# 12                                   Morgan Wallen
# 13                      PinkPantheress & Ice Spice
# 14                                  Meghan Trainor
# 15                                     Chris Brown
# 16                                            JVKE
# 17                                   Morgan Wallen
# 18                                Bailey Zimmerman
# 19                                      Zach Bryan
# 20                   Kane Brown With Katelyn Brown
# 21                                      Steve Lacy
# 22                                      Luke Combs
# 23                        RAYE Featuring 070 Shake
# 24              Metro Boomin, Future & Chris Brown
# 25                                    Taylor Swift
# 26                             Rema & Selena Gomez
# 27                                       Coi Leray
# 28                                             SZA
# 29                                          Miguel
# 30                                      Luke Combs
# 31                                   Lainey Wilson
# 32                              Bizarrap & Shakira
# 33                                             SZA
# 34                                 Stephen Sanchez
# 35                   Future Featuring Drake & Tems
# 36                  Post Malone Featuring Doja Cat
# 37                                   Morgan Wallen
# 38                  Fuerza Regida X Grupo Frontera
# 39                              GloRilla & Cardi B
# 40                                           Lizzo
# 41                   HARDY Featuring Lainey Wilson
# 42                                   Cole Swindell
# 43                                             SZA
# 44                                    Jordan Davis
# 45                                             Sia
# 46                                   Morgan Wallen
# 47                                      Nate Smith
# 48              Zach Bryan Featuring Maggie Rogers
# 49                                   The Kid LAROI
# 50                                   Morgan Wallen
# 51                                         Rihanna
# 52                     Carin Leon X Grupo Frontera
# 53                                             SZA
# 54                                   Megan Moroney
# 55                          Karol G x Romeo Santos
# 56                                       Lady Gaga
# 57                                 Parker McCollum
# 58                                    Carly Pearce
# 59                                        Lil Baby
# 60                                      Corey Kent
# 61                               Drake & 21 Savage
# 62                                     Brett Young
# 63                                      Luke Combs
# 64                               Sabrina Carpenter
# 65                                            d4vd
# 66                                      Tory Lanez
# 67  Gabito Ballesteros, Peso Pluma & Natanael Cano
# 68                     Tiesto Featuring Tate McRae
# 69                                   Manuel Turizo
# 70                                   Lewis Capaldi
# 71                                      Hotel Ugly
# 72                                             SZA
# 73                                        NewJeans
# 74                                  Grupo Frontera
# 75                                          Future
# 76                            Arcangel & Bad Bunny
# 77                      Peso Pluma X Natanael Cano
# 78                                    Jason Aldean
# 79                                             SZA
# 80                                   Morgan Wallen
# 81                                        NewJeans
# 82                              Falling In Reverse
# 83                                    Cody Johnson
# 84                                       Ice Spice
# 85                                   Finesse2Tymes
# 86                              NLE Choppa & 2Rare
# 87                            Ozuna Featuring Feid
# 88     Metro Boomin Featuring Don Toliver & Future
# 89                   SZA Featuring Phoebe Bridgers
# 90                         Junior H X Oscar Maydon
# 91                                       Rosa Linn
# 92                                        Lil Baby
# 93                                       Sam Smith
# 94                          Nengo Flow & Bad Bunny
# 95                                   Yandel & Feid
# 96                                     Mac DeMarco
# 97                                    Jordan Davis
# 98                                            P!nk
# 99                      SZA Featuring Travis Scott

# %%
hotsongs2 = hotsongs.copy()
duplicated_entry = {"songs":"Flowers", "artist":"ABC"}
hotsongs2 = hotsongs2.append(duplicated_entry, ignore_index=True)
hotsongs2
# Out:
# /var/folders/rd/g86s3t0n2qg0z79f8ywnk8ym0000gn/T/ipykernel_89811/3017195727.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hotsongs2 = hotsongs2.append(duplicated_entry, ignore_index=True)
#                              songs  \
# 0                          Flowers
# 1                        Kill Bill
# 2                       Last Night
# 3                           Unholy
# 4                         Creepin'
# 5                          Cuff It
# 6                        Anti-Hero
# 7                      Die For You
# 8                  I'm Good (Blue)
# 9                        As It Was
# 10                       Rich Flex
# 11                 Just Wanna Rock
# 12         Thought You Should Know
# 13             Boy's A Liar, Pt. 2
# 14                   Made You Look
# 15             Under The Influence
# 16                     Golden Hour
# 17                       You Proof
# 18           Rock And A Hard Place
# 19         Something In The Orange
# 20                       Thank God
# 21                       Bad Habit
# 22              Going, Going, Gone
# 23                        Escapism
# 24   Superhero (Heroes & Villains)
# 25                   Lavender Haze
# 26                       Calm Down
# 27                         Players
# 28                           Shirt
# 29                      Sure Thing
# 30        The Kind Of Love We Make
# 31              Heart Like A Truck
# 32    Bzrp Music Sessions, Vol. 53
# 33                          Snooze
# 34               Until I Found You
# 35                      Wait For U
# 36     I Like You (A Happier Song)
# 37                I Wrote The Book
# 38                       Bebe Dame
# 39                      Tomorrow 2
# 40                 About Damn Time
# 41               Wait In The Truck
# 42    She Had Me At Heads Carolina
# 43                  Nobody Gets Me
# 44      What My World Spins Around
# 45                     Unstoppable
# 46             One Thing At A Time
# 47                  Whiskey On You
# 48                           Dawns
# 49                      Love Again
# 50               Everything I Love
# 51                      Lift Me Up
# 52                     Que Vuelvas
# 53                             Low
# 54                Tennessee Orange
# 55                   X Si Volvemos
# 56                     Bloody Mary
# 57                   Handle On You
# 58               What He Didn't Do
# 59                       Freestyle
# 60                     Wild As Her
# 61                     Spin Bout U
# 62                      You Didn't
# 63      Growin' Up And Gettin' Old
# 64                        Nonsense
# 65                    Here With Me
# 66                The Color Violet
# 67                             AMG
# 68                           10:35
# 69                      La Bachata
# 70                       Forget Me
# 71         Shut Up My Moms Calling
# 72                           Blind
# 73                             OMG
# 74                        No Se Va
# 75                 Love You Better
# 76                        La Jumpa
# 77                             PRC
# 78        That's What Tequila Does
# 79                   Love Language
# 80                   Tennessee Fan
# 81                           Ditto
# 82            Watch The World Burn
# 83                           Human
# 84                      In Ha Mood
# 85                        Back End
# 86                     Do It Again
# 87                         Hey Mor
# 88                 Too Many Nights
# 89            Ghost In The Machine
# 90                   Fin de Semana
# 91                            Snap
# 92               California Breeze
# 93    I'm Not Here To Make Friends
# 94                   Gato de Noche
# 95                      Yandel 150
# 96                  Heart To Heart
# 97             Next Thing You Know
# 98     Never Gonna Not Dance Again
# 99                       Open Arms
# 100                        Flowers
#
#                                              artist
# 0                                       Miley Cyrus
# 1                                               SZA
# 2                                     Morgan Wallen
# 3                            Sam Smith & Kim Petras
# 4              Metro Boomin, The Weeknd & 21 Savage
# 5                                           Beyonce
# 6                                      Taylor Swift
# 7                                        The Weeknd
# 8                         David Guetta & Bebe Rexha
# 9                                      Harry Styles
# 10                                Drake & 21 Savage
# 11                                     Lil Uzi Vert
# 12                                    Morgan Wallen
# 13                       PinkPantheress & Ice Spice
# 14                                   Meghan Trainor
# 15                                      Chris Brown
# 16                                             JVKE
# 17                                    Morgan Wallen
# 18                                 Bailey Zimmerman
# 19                                       Zach Bryan
# 20                    Kane Brown With Katelyn Brown
# 21                                       Steve Lacy
# 22                                       Luke Combs
# 23                         RAYE Featuring 070 Shake
# 24               Metro Boomin, Future & Chris Brown
# 25                                     Taylor Swift
# 26                              Rema & Selena Gomez
# 27                                        Coi Leray
# 28                                              SZA
# 29                                           Miguel
# 30                                       Luke Combs
# 31                                    Lainey Wilson
# 32                               Bizarrap & Shakira
# 33                                              SZA
# 34                                  Stephen Sanchez
# 35                    Future Featuring Drake & Tems
# 36                   Post Malone Featuring Doja Cat
# 37                                    Morgan Wallen
# 38                   Fuerza Regida X Grupo Frontera
# 39                               GloRilla & Cardi B
# 40                                            Lizzo
# 41                    HARDY Featuring Lainey Wilson
# 42                                    Cole Swindell
# 43                                              SZA
# 44                                     Jordan Davis
# 45                                              Sia
# 46                                    Morgan Wallen
# 47                                       Nate Smith
# 48               Zach Bryan Featuring Maggie Rogers
# 49                                    The Kid LAROI
# 50                                    Morgan Wallen
# 51                                          Rihanna
# 52                      Carin Leon X Grupo Frontera
# 53                                              SZA
# 54                                    Megan Moroney
# 55                           Karol G x Romeo Santos
# 56                                        Lady Gaga
# 57                                  Parker McCollum
# 58                                     Carly Pearce
# 59                                         Lil Baby
# 60                                       Corey Kent
# 61                                Drake & 21 Savage
# 62                                      Brett Young
# 63                                       Luke Combs
# 64                                Sabrina Carpenter
# 65                                             d4vd
# 66                                       Tory Lanez
# 67   Gabito Ballesteros, Peso Pluma & Natanael Cano
# 68                      Tiesto Featuring Tate McRae
# 69                                    Manuel Turizo
# 70                                    Lewis Capaldi
# 71                                       Hotel Ugly
# 72                                              SZA
# 73                                         NewJeans
# 74                                   Grupo Frontera
# 75                                           Future
# 76                             Arcangel & Bad Bunny
# 77                       Peso Pluma X Natanael Cano
# 78                                     Jason Aldean
# 79                                              SZA
# 80                                    Morgan Wallen
# 81                                         NewJeans
# 82                               Falling In Reverse
# 83                                     Cody Johnson
# 84                                        Ice Spice
# 85                                    Finesse2Tymes
# 86                               NLE Choppa & 2Rare
# 87                             Ozuna Featuring Feid
# 88      Metro Boomin Featuring Don Toliver & Future
# 89                    SZA Featuring Phoebe Bridgers
# 90                          Junior H X Oscar Maydon
# 91                                        Rosa Linn
# 92                                         Lil Baby
# 93                                        Sam Smith
# 94                           Nengo Flow & Bad Bunny
# 95                                    Yandel & Feid
# 96                                      Mac DeMarco
# 97                                     Jordan Davis
# 98                                             P!nk
# 99                       SZA Featuring Travis Scott
# 100                                             ABC

# %%
def transform_database(reference_database):
    return reference_database.applymap(lambda x: x.lower().title())

# %%
def get_user_input():
    user_input = input("Please provide a song: ").lower().title()
    return user_input

# %%
def check_duplicates(song_name, reference_database, title_column, artist_column):
    if (reference_database[title_column] == song_name).sum() > 1:
        duplicates = list(reference_database[reference_database[title_column] == song_name][artist_column].values)
        additional_artist_input = pyip.inputMenu(duplicates, prompt = "There seem to be duplicated entries. Which of the following artists do you meant: \n")
        return additional_artist_input
    else:
        pass

# %%
def check_mistakes(song_name, reference_database, title_column, artist_column):
    best_match, score = process.extractOne(song_name, reference_database[title_column].values)
    if score >= 80:
        artists = reference_database[reference_database[title_column] == best_match][artist_column].values
        answer = pyip.inputYesNo(prompt = f"Did you mean {best_match} by {artists}? Y/N: ")
        if answer.lower().title() in ["Yes", "Y"]:
            return best_match
        else:
            pass
            
    else:
        pass

# %%
def recommend_hot_song(reference_database, title_column, artist_column):

    song_input = get_user_input()
    
    while song_input not in list(reference_database[title_column]):
            song_input = input("Sorry there seems no matching song available. Please provide another song: ").lower().title()
            song_input = check_mistakes(song_input, reference_database, title_column, artist_column)
    
    additional_artist_input = check_duplicates(song_input, reference_database, title_column, artist_column)
    
    random_song_index = random.randint(0, len(reference_database[title_column])-1)
    random_song = reference_database[title_column][random_song_index]
    random_artist = reference_database[artist_column][random_song_index]
    return random_song, random_artist

# %%
recommend_hot_song(hotsongs2, "songs", "artist")
# Out:
# Please provide a song: flowers
# There seem to be duplicated entries. Which of the following artists do you meant:
# * Miley Cyrus
# * ABC
# abc
# ('X Si Volvemos', 'Karol G x Romeo Santos')

# %% [markdown]
# Functionality
#
# - Sobald Lehrzeichen oder andere Zeichen/Typos eingefügt werden sollen diese entfern werden
# - Sobald ein artist eingegeben wurde, fordere den User auf, einen Song statt einem artist einzugeben
# - Sofern Duplikate angezeigt werden, sollten alle angezeigt werden
# - Display youtube link to the song the user inserted
# - If only part of the song is displayed, also find the song
# - EXTRA: display the different options of the song
# - Was passiert wenn "The" davor gesetzt wird
#
# Done:
# - Rechtschreibung (transformation der eingabe in Upper + Lowercase) (DONE)
# - Falls song nicht gefunden wird sollte zunächst ein error ausgeworfen werden (DONE); später soll dann eine andere Funktion geschrieben werden
#
# In Progress:

# %% [markdown]
# ## 2. Spotify API

# %% [markdown]
# ### Basic Spotify API Setup

# %%
import config

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#connect to spotify
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
#Send request to API
results = sp.search(q="Lose yourself",limit=1,market="US")
#sp.audio_features(results["tracks"]["items"][0]["id"] )

# %% [markdown]
# ### Song Feature Extraction

# %%
#Extracting features of songs and appending them to dataframe
list_of_songs=[]
for index in range(0,len(song["tracks"]["items"])):
    list_of_songs.append(sp.audio_features(song["tracks"]["items"][index]["uri"])[0])
df=pd.DataFrame(list_of_songs)
df=df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

# %% [markdown]
# ### Playlist

# %%
#Extracting the songs ids from playlist
list_of_audio_features=[]
for item in range(0,10):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])
df=pd.DataFrame(list_of_audio_features)    
df=df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

# %%
#Searching a playlist
playlist = sp.user_playlist_tracks("spotify", "7beGd4yYY1qpsBv6K3clFZ",market="GB")

# %%
#Extracting songs of playlist
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %% [markdown]
# ### Artists

# %%
Question: how to get the playlist ID?

# %%
#Extract artists from track
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %%
#Extract artists from playlist
def get_artists_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %% [markdown]
# ### Albums

# %%
#Extract all tracks of one artist
def get_albums_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50,country="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
#Extract all albums ID of one artist
def get_album_ids_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return [track["id"] for track in tracks]

# %%
#Check 
set([artist["name"] for track in coldplay_albums for artist in track["artists"]])

# %%
#Extracting songs of given album
def get_track_ids_from_albums(album_ids):
    return list(set([i["id"] for j in album_ids for i in sp.album(j)["tracks"]["items"]]))

# %% [markdown]
# ### Pipeline

# %%
#setup
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
#Identify spotify markets
markets = sp.available_markets()["markets"]

# %%
#Identify genres per markets & store them in dictionary
genres_per_country = {}

for market in markets:
    genres_per_country.update({market:{}})
    for category in sp.categories(country=str(market), limit=50)["categories"]["items"]:
        genres_per_country[market].update({category["name"]: category["id"]})

# %%
#Identify playlist_ids per market and per genre & store them in dictionary
from random import randint
from time import sleep

for market in markets:
    for category in genres_per_country[market]:
        try:
            genres_per_country[market].update({category: [genres_per_country[market][category], sp.category_playlists(category_id = genres_per_country[market][category], country = market, limit = 1)["playlists"]["items"][0]["id"]]})
        except:
            pass

# %%
#Format: Country: Category: Category_ID, Sample Playlist_ID
genres_per_country

# %%
sample = genres_per_country.copy()

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
#Clean the playlist_ids
playlist__id_list = []
for market in markets:
    for category in sample[market]:
        playlist__id_list.append(sample[market][category][1])

# %%
#Check length of unclean playist_id list
len(playlist__id_list)

# %%
#Check length of unclean playist_id set -> There seems to be more than 7000 duplicates
len(set(playlist__id_list))

# %%
#Create final list of playlists
final_list = list(set(playlist__id_list))

# %%
#Get information of first 10 songs of each playlist
df_info = []

for playlist_id in final_list:
    for i in range(10):
        try:
            song_id = get_playlist_tracks("spotify", playlist_id)[i]["track"]["id"]
            df_info.append(sp.audio_features(song_id)[0])
        except:
            pass

# %%
#Append each gathered information to dataframe
df=pd.DataFrame(df_info) 
df=df[["danceability","energy","loudness","speechiness","acousticness","instrumentalness","liveness","valence","tempo","id","duration_ms"]]
df

# %%
df.to_csv("final.csv")

# %%
#Clean dataframe for multiple entries
df.duplicated().value_counts()

# %%
import base64
import requests

# Set up authorization headers
client_id = config.client_id
client_secret = config.client_secret
auth_header = base64.b64encode(f"{client_id}:{client_secret}".encode("ascii")).decode("ascii")
headers = {"Authorization": f"Basic {auth_header}"}

# Get access token
url = "https://accounts.spotify.com/api/token"
data = {"grant_type": "client_credentials"}
response = requests.post(url, headers=headers, data=data)
access_token = response.json()["access_token"]

# Make request to Top Tracks endpoint
artist_id = "0OdUWJ0sBjDrqHygGUXeCF"  # example artist ID
url = f"https://api.spotify.com/v1/artists/{artist_id}/top-tracks"
headers = {"Authorization": f"Bearer {access_token}"}
params = {"market": "US"}

response = requests.get(url, headers=headers, params=params)
